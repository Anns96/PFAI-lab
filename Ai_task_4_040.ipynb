# %%
def is_safe(board, row, col, n):
    for i in range(row):
        if board[i] == col:
            return False
    for i, j in zip(range(row, -1, -1), range(col, -1, -1)):
        if i < 0 or j < 0:
            break
        if board[i] == j:
            return False
    for i, j in zip(range(row, -1, -1), range(col, n)):
        if i < 0 or j >= n:
            break
        if board[i] == j:
            return False
    return True
def solve_nqueens(board, row, n, solutions):
    if row == n:
        solutions.append(board.copy())
        return
    for col in range(n):
        if is_safe(board, row, col, n):
            board[row] = col
            solve_nqueens(board, row + 1, n, solutions)
            board[row] = -1
def print_solution(solution, n):
    for row in solution:
        line = ""
        for col in range(n):
            if col == row:
                line += " Q "
            else:
                line += " . "
        print(line)
    print("\n")
n = int(input("enter number for N-Queens: "))
board = [-1] * n
solutions = []
solve_nqueens(board, 0, n, solutions)
print(f"\ntotal solutions for {n}-Queens = {len(solutions)}\n")
for sol in solutions:
    print_solution(sol, n)
# Out:
# enter number for N-Queens: 6
#
# total solutions for 6-Queens = 4
#
#  .  Q  .  .  .  .
#  .  .  .  Q  .  .
#  .  .  .  .  .  Q
#  Q  .  .  .  .  .
#  .  .  Q  .  .  .
#  .  .  .  .  Q  .
#
#
#  .  .  Q  .  .  .
#  .  .  .  .  .  Q
#  .  Q  .  .  .  .
#  .  .  .  .  Q  .
#  Q  .  .  .  .  .
#  .  .  .  Q  .  .
#
#
#  .  .  .  Q  .  .
#  Q  .  .  .  .  .
#  .  .  .  .  Q  .
#  .  Q  .  .  .  .
#  .  .  .  .  .  Q
#  .  .  Q  .  .  .
#
#
#  .  .  .  .  Q  .
#  .  .  Q  .  .  .
#  Q  .  .  .  .  .
#  .  .  .  .  .  Q
#  .  .  .  Q  .  .
#  .  Q  .  .  .  .
